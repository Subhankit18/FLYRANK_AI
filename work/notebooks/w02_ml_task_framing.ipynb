# %% [markdown]
# # ML-03 — Frame Your Lane as an ML Task
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Subhankit18/FLYRANK_AI/blob/main/work/notebooks/w02_ml_task_framing.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane as an ML task (type)
# My lane is ranking. The goal is to rank content pages by how likely they are to be declining, so that the highest-priority pages can be reviewed first. Ranking fits this problem because the practical decision is not simply whether a page is declining; it is which pages should be reviewed first when review capacity is limited.## 1. My lane as an ML task (type)
#
# *Classification, clustering, ranking, or scoring — which one, and why?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# The target is whether a content page is declining. I use the observed trend_direction field to define the binary label: 1 when trend_direction is "down" and 0 otherwise. This is an observed outcome in the available dataset rather than a label created from the model's predictions. The target is therefore a proxy for identifying pages that may need refresh or review.## 2. Target or proxy
#
# *What would you predict? Where does that label come from — observed outcome or a defined rule?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# My main success metric is Precision@50. It measures the proportion of the top 50 ranked pages that are actually labeled as declining. This matches the practical use case because a reviewer has limited capacity and needs the highest-value pages at the top of the queue. A higher Precision@50 means fewer review slots are spent on pages that are not declining## 3. Success metric
#
# *One metric you can defend. What number means 'good'?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# The unit of analysis is one content page. Each row represents one unique content_id, with its search visibility, traffic, engagement, freshness, position, and trend information.## 4. The unit of analysis, as a real dataframe
#
# *Load your lane's slice and show it: one row = one what?*

# %%
import pandas as pd
from pathlib import Path

# Locate the prepared feature vector
feature_path = Path("../../data/processed/refresh_feature_vector.csv")

df = pd.read_csv(feature_path)

print("Rows:", len(df))
print("Columns:", len(df.columns))

display(df.head())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_3283/3699902958.py in <cell line: 0>()
#       5 feature_path = Path("../../data/processed/refresh_feature_vector.csv")
#       6
# ----> 7 df = pd.read_csv(feature_path)
#       8
#       9 print("Rows:", len(df))
#
# ...

# %% [markdown]
# A fixed rule can capture obvious signals, but the relationship between page performance and decline is more complicated than a few manually chosen thresholds. Pages differ in visibility, freshness, search position, content depth, traffic, engagement, and other characteristics. A machine-learning model can learn combinations of these signals from observed outcomes instead of relying only on fixed weights. The fixed rule will therefore be kept as a baseline and the ML model will need to demonstrate that it improves the ranking of declining pages.## 5. Why ML beats a fixed rule here
#
# *What makes the pattern too messy for an if-statement?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
